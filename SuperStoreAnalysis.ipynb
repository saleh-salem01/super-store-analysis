# %%
import pandas as pd

# %%
df = pd.read_csv('Sample - Superstore.csv')

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data = df.drop(['Row ID', 'Order ID','Postal Code','Product ID','Customer ID'],axis=1)

# %%
data.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Customer Name    Segment  \
# 0   11/8/2016  11/11/2016    Second Class      Claire Gute   Consumer
# 1   11/8/2016  11/11/2016    Second Class      Claire Gute   Consumer
# 2   6/12/2016   6/16/2016    Second Class  Darrin Van Huff  Corporate
# 3  10/11/2015  10/18/2015  Standard Class   Sean O'Donnell   Consumer
# 4  10/11/2015  10/18/2015  Standard Class   Sean O'Donnell   Consumer
#
#          Country             City       State Region         Category  \
# 0  United States        Henderson    Kentucky  South        Furniture
# 1  United States        Henderson    Kentucky  South        Furniture
# 2  United States      Los Angeles  California   West  Office Supplies
# 3  United States  Fort Lauderdale     Florida  South        Furniture
# 4  United States  Fort Lauderdale     Florida  South  Office Supplies
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
no=data.groupby(data.Country).nunique()

# %%
no
# Out:
#                Order Date  Ship Date  Ship Mode  Customer Name  Segment  City  \
# Country
# United States        1237       1334          4            793        3   531
#
#                State  Region  Category  Sub-Category  Product Name  Sales  \
# Country
# United States     49       4         3            17          1850   5825
#
#                Quantity  Discount  Profit
# Country
# United States        14        12    7287

# %% [markdown]
# ## it seems that there is no diffirente countries all of the orders in U.S.A

# %%
data=data.drop(['Country'],axis=1)

# %%
data.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Customer Name    Segment  \
# 0   11/8/2016  11/11/2016    Second Class      Claire Gute   Consumer
# 1   11/8/2016  11/11/2016    Second Class      Claire Gute   Consumer
# 2   6/12/2016   6/16/2016    Second Class  Darrin Van Huff  Corporate
# 3  10/11/2015  10/18/2015  Standard Class   Sean O'Donnell   Consumer
# 4  10/11/2015  10/18/2015  Standard Class   Sean O'Donnell   Consumer
#
#               City       State Region         Category Sub-Category  \
# 0        Henderson    Kentucky  South        Furniture    Bookcases
# 1        Henderson    Kentucky  South        Furniture       Chairs
# 2      Los Angeles  California   West  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  South        Furniture       Tables
# 4  Fort Lauderdale     Florida  South  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# ...

# %%
# customer name is not useful in the analysis
data = data.drop(['Customer Name'],axis=1)

# %%
data.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Segment             City  \
# 0   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 1   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 2   6/12/2016   6/16/2016    Second Class  Corporate      Los Angeles
# 3  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
# 4  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
#
#         State Region         Category Sub-Category  \
# 0    Kentucky  South        Furniture    Bookcases
# 1    Kentucky  South        Furniture       Chairs
# 2  California   West  Office Supplies       Labels
# 3     Florida  South        Furniture       Tables
# 4     Florida  South  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# ...

# %%
data.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Segment', 'City', 'State',
#        'Region', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # What are the most selling sections?

# %%
sell_section=data.groupby('Category')['Quantity'].sum()

# %%
sell_section=pd.DataFrame(data.groupby('Category')['Quantity'].sum())

# %%
sell_section
# Out:
#                  Quantity
# Category
# Furniture            8028
# Office Supplies     22906
# Technology           6939

# %%
import matplotlib.pyplot as plt

# %%
x = sell_section.index
y = sell_section.Quantity
plt.bar(x,y,width = 0.6)
plt.xlabel("Category")
plt.ylabel("Quantity")
#plt.grid()
plt.show()

# %% [markdown]
# #### Conclusion: the office Supplies Category is the most selling section.

# %%
data['Product Name'][220]
# Out:
# 'While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle'

# %% [markdown]
# # the best sell

# %%
data_cat =pd.DataFrame(data.groupby('Category')['Sales'].sum())

# %%
data_cat.head()
# Out:
#                        Sales
# Category
# Furniture        741999.7953
# Office Supplies  719047.0320
# Technology       836154.0330

# %%
x = data_cat.index
y = data_cat.Sales
plt.bar(x,y,width = 0.4)
plt.xlabel("Category")
plt.ylabel("Sales")
#plt.grid()
plt.show()

# %% [markdown]
# # the best city

# %%
city_sell=data.groupby('City')['Quantity','Sales'].sum()
# Out:
# <ipython-input-24-b26b12a87037>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   city_sell=data.groupby('City')['Quantity','Sales'].sum()

# %%
city_sell.shape
# Out:
# (531, 2)

# %%
city_sell.head()
# Out:
#              Quantity     Sales
# City
# Aberdeen            3    25.500
# Abilene             2     1.392
# Akron              65  2729.986
# Albuquerque        65  2220.160
# Alexandria         84  5519.570

# %% [markdown]
# ### The number of cities is too large and results are not clear when representing the data
# ### We can have the top 20 selling cities and they will be the best sellers

# %%
maxCity=city_sell.nlargest(20, 'Quantity')

# %%
Labels=maxCity.index
x= maxCity.Sales
#plt.title('the most City')
#plt.xlabel('City')
#plt.ylabel('Quantity')
plt.pie(x,labels=Labels,radius=2.3)
#plt.xticks(Labels,rotation=90)
plt.show()

# %%
data.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Segment             City  \
# 0   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 1   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 2   6/12/2016   6/16/2016    Second Class  Corporate      Los Angeles
# 3  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
# 4  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
#
#         State Region         Category Sub-Category  \
# 0    Kentucky  South        Furniture    Bookcases
# 1    Kentucky  South        Furniture       Chairs
# 2  California   West  Office Supplies       Labels
# 3     Florida  South        Furniture       Tables
# 4     Florida  South  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# ...

# %% [markdown]
# ## How many unique products are sold ?
# ### the number is 1850 unique product

# %%
pp=pd.unique(data['Product Name'])

# %%
len(pp)
# Out:
# 1850

# %% [markdown]
# ## what is the most seld product?

# %%
maxp=pd.DataFrame(data.groupby('Product Name')['Quantity'].sum())

# %%
maxProduct = maxp.nlargest(20, 'Quantity')

# %%
maxProduct
# Out:
#                                                     Quantity
# Product Name
# Staples                                                  215
# Staple envelope                                          170
# Easy-staple paper                                        150
# Staples in misc. colors                                   86
# KI Adjustable-Height Table                                74
# Avery Non-Stick Binders                                   71
# Storex Dura Pro Binders                                   71
# GBC Premium Transparent Covers with Diagonal Li...        67
# Situations Contoured Folding Chairs, 4/Set                64
# Staple-based wall hangings                                62
# Chromcraft Round Conference Tables                        61
# Eldon Wave Desk Accessories                               61
# Staple remover                                            61
# Global Wood Trimmed Manager's Task Chair, Khaki           59
# ...

# %%
x = maxProduct.index
y = maxProduct.Quantity
plt.bar(x,y,width = 0.6,)
plt.xlabel("Product")
plt.ylabel("Quantity")
plt.xticks(x,rotation=90)
#plt.grid()
plt.show()

# %%
data.head()
# Out:
#    Order Date   Ship Date       Ship Mode    Segment             City  \
# 0   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 1   11/8/2016  11/11/2016    Second Class   Consumer        Henderson
# 2   6/12/2016   6/16/2016    Second Class  Corporate      Los Angeles
# 3  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
# 4  10/11/2015  10/18/2015  Standard Class   Consumer  Fort Lauderdale
#
#         State Region         Category Sub-Category  \
# 0    Kentucky  South        Furniture    Bookcases
# 1    Kentucky  South        Furniture       Chairs
# 2  California   West  Office Supplies       Labels
# 3     Florida  South        Furniture       Tables
# 4     Florida  South  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# ...

# %%
data=data.drop('Ship Mode',axis=1)

# %%
data.head()
# Out:
#    Order Date   Ship Date    Segment             City       State Region  \
# 0   11/8/2016  11/11/2016   Consumer        Henderson    Kentucky  South
# 1   11/8/2016  11/11/2016   Consumer        Henderson    Kentucky  South
# 2   6/12/2016   6/16/2016  Corporate      Los Angeles  California   West
# 3  10/11/2015  10/18/2015   Consumer  Fort Lauderdale     Florida  South
# 4  10/11/2015  10/18/2015   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# ...

# %% [markdown]
# ## What product that gives the most profit?

# %%
max_Profit=pd.DataFrame(data.groupby('Product Name')['Profit'].sum())
max_maxProfit = max_Profit.nlargest(20, 'Profit')

# %%
max_maxProfit
# Out:
#                                                         Profit
# Product Name
# Canon imageCLASS 2200 Advanced Copier               25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Bind...   7753.0390
# Hewlett Packard LaserJet 3310 Copier                 6983.8836
# Canon PC1060 Personal Laser Copier                   4570.9347
# HP Designjet T520 Inkjet Large Format Printer -...   4094.9766
# Ativa V4110MDD Micro-Cut Shredder                    3772.9461
# 3D Systems Cube Printer, 2nd Generation, Magenta     3717.9714
# Plantronics Savi W720 Multi-Device Wireless Hea...   3696.2820
# Ibico EPK-21 Electric Binding System                 3345.2823
# Zebra ZM400 Thermal Label Printer                    3343.5360
# Honeywell Enviracaire Portable HEPA Air Cleaner...   3247.0200
# Hewlett Packard 610 Color Digital Copier / Printer   3124.9375
# Plantronics CS510 - Over-the-Head monaural Wire...   3085.0325
# Canon Imageclass D680 Copier / Fax                   2799.9600
# ...

# %%
x = max_maxProfit.index
y = max_maxProfit.Profit
plt.bar(x,y,width = 0.6,)
plt.xlabel("Product")
plt.ylabel("Profit")
plt.xticks(x,rotation=90)
#plt.grid()
plt.show()

# %%
seg_sell=pd.DataFrame(data.groupby('Segment')['Quantity'].count())

# %%
seg_sell
# Out:
#              Quantity
# Segment
# Consumer         5191
# Corporate        3020
# Home Office      1783

# %%
x = seg_sell.index
y = seg_sell.Quantity
plt.bar(x,y,width = 0.6,)
plt.xlabel("Segment")
plt.ylabel("number of orders")
plt.xticks(x)
#plt.grid()
plt.show()
